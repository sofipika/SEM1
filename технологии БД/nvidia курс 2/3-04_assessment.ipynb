# %% [markdown]
# <div align="center"><a href="https://www.nvidia.com/en-us/deep-learning-ai/education/"><img src="./images/DLI_Header.png"></a></div>

# %% [markdown]
# Welcome to the assessment for this course. While we have gone over a variety of algorithms, we haven't done the most important part. We still need to serve a user a recommendation!
#
# Not a problem. We have all the pieces, time to put them together. For this assessment, we've constructed a skeleton for an end-to-end recommender system by copying over some code from Labs 1 and 2. By using what we've learned about the strengths and weaknesses of these algorithms, it will be up to you to apply them in the correct places.
#
# The code we have from the previous lab is:
# * [als.py](assessment/als.py) - Train and predict with an alternating least squares model
# * [dataset.py](assessment/dataset.py) - Prepare a dataset into a tf.data
# * [wide_and_deep.py](assessment/wide_and_deep.py) Construct a Wide & Deep TensorFlow model
# * [utils.py](assessment/utils.py) - Helper functions such as calculating RMSE
#
# As a reference, we can also unzip the packaged notebooks from the previous lab by uploading them (with the upward pointing arrow above the file menu) and running the cell block below. Please keep in mind that these previous lab notebooks won't run in this lab3 coding environment.

# %%
# !unzip lab1_work.zip -d lab1/
# !unzip lab2_work.zip -d lab2/
# Out:
# unzip:  cannot find or open lab1_work.zip, lab1_work.zip.zip or lab1_work.zip.ZIP.
# unzip:  cannot find or open lab2_work.zip, lab2_work.zip.zip or lab2_work.zip.ZIP.

# %% [markdown]
# Let's get started. Here's the total pipeline we'll be constructing.
#
# <img src="images/endtoend.png" height="300" width="500"/>
#
# The goal is to create two python files, [trainer.py](assessment/trainer.py) and [client.py](assessment/client.py). [trainer.py](assessment/trainer.py) will train both the Candidate Generator Model and the Candidate Scoring Model. [client.py](assessment/client.py) will return recommendations for a specified user from Triton.
#
# ## Scoring
# * [1. Model Training](#1.-Model-Training)
#  * [1.1 Candidate Generator Model](#1.1-Candidate-Generator-Model) - `30 Points`
#  * [1.2 Candidate Scoring Model](#1.2-Candidate-Scoring-Model) - `30 Points`
# * [2. Model Deployment](#2.-Model-Deployment)
#  * [2.1 Triton](#2.1-Triton) - `20 Points`
#  * [2.2 Client Application](#2.2-Client-Application) - `20 Points`
#
# ## 1. Model Training
#
# In [trainer.py](assessment/trainer.py), we have four functions:
# * `get_als_model`: Initializes and trains an ALS Model
# * `get_wide_and_deep_model`: Initializes and trains a Wide & Deep Model
# * `get_candidate_generator`: Creates a Candidate Generator Model
# * `get_candidate_scoring_model`: Creates a Candidate Scoring Model
#
# Each of them have a number of `FIXME`s.
#
# ### 1.1 Candidate Generator Model
# For `get_candidate_generator`, implement either a ALS (`get_als_model`) or Wide & Deep model (`get_wide_and_deep_model`). It will be trained on the ratings data below.

# %%
import pandas as pd

ratings = pd.read_csv("data/task_3_ratings.csv")
ratings.head()
# Out:
#    user_index  item_index  overall  valid
# 0      180332         781      1.0  False
# 1       55433         781      2.0  False
# 2       34202         781      5.0  False
# 3       77087         781      4.0  False
# 4       67012         781      1.0  False

# %% [markdown]
# The Candidate Generator is focused on speed, and is meant to quickly reduce our item catalogue down to a few hundred that our user might like.
#
# One way we can speed up predictions for our users is to cache the results of the Candidate Generator. If we do this, including contextual information such as time and location is not so straightforward. We would need to cache different results for different combinations of time and place for the variety of different ways users can interact with our system.
#
# Let's keep things simple for now, and instead just focus on `user_index`, `item_index`, and `overall`.
#
# Whether ALS or Wide and Deep is chosen, the Candidate Generator must be fast in both training and prediction:
#
# * The Candidate Generator should be trained in less than 15 seconds `10 points`.
# * The Candidate Generator should have a Root Mean Squared Error of less than 1.3 on the Validation Dataset `10 points`.
# * The Candidate Generator should make predictions for the Validation Dataset in 0.005 seconds `10 points`.
#
# **While either algorithm can hypothetically pass these requirements, one will be significantly easier to implement than the other.**
#
# ### 1.2 Candidate Scoring Model
#
# The goal of the Candidate Scorer Model is to take the candidates from the Generator Model, and to rank them in order of the user's predicted preference. While the Generator Model is focused on speed, the Scoring Model is focused on accuracy. Additionally, the Scoring Model can more easily incorporate contextual information as it is ran when a user asks for a recommendation.
#
# When we trained our Wide and Deep Model in Lab 2, our `metadata` was already joined with user rankings. However, in production when we're making a prediction for one user, our predictions will be based on our separate metadata table:

# %%
metadata = pd.read_csv("data/task_3_metadata.csv")
metadata.head()
# Out:
#    item_index  brand_index category_0_0                 category_0_1  \
# 0           0            0  Electronics             GPS & Navigation
# 1           1            0  Electronics      Computers & Accessories
# 2           2          337  Electronics  eBook Readers & Accessories
# 3           3         3146  Electronics       Accessories & Supplies
# 4           4            0  Electronics      Computers & Accessories
#
#                       category_0_2            category_0_3 category_1_0  \
# 0                      Vehicle GPS            Trucking GPS          NaN
# 1  Touch Screen Tablet Accessories     Chargers & Adapters          NaN
# 2                   Power Adapters                     NaN          NaN
# 3        Audio & Video Accessories  TV Accessories & Parts          NaN
# 4                          Tablets                     NaN          NaN
#
#   category_1_1 category_1_2 category_1_3  ...  category_1_2_index  \
# 0          NaN          NaN          NaN  ...                 101
# 1          NaN          NaN          NaN  ...                 101
# 2          NaN          NaN          NaN  ...                 101
# 3          NaN          NaN          NaN  ...                 101
# 4          NaN          NaN          NaN  ...                 101
#
#    salesRank_Electronics  salesRank_Camera  salesRank_Computers  \
# 0               147236.0           18665.5              14369.5
# 1               147236.0           18665.5              14369.5
# 2               147236.0           18665.5              14369.5
# 3               147236.0           18665.5              14369.5
# 4               147236.0           18665.5              14369.5
#
#    salesRank_CellPhones  salesRank_CellPhones_NA  salesRank_Electronics_NA  \
# 0              254050.0                    False                     False
# 1              254050.0                    False                     False
# 2              254050.0                    False                     False
# 3              254050.0                    False                     False
# 4              254050.0                    False                     False
#
#    salesRank_Camera_NA  salesRank_Computers_NA  price_filled
# 0                False                   False        299.99
# 1                False                   False         49.95
# 2                False                   False         19.65
# 3                False                   False         29.99
# 4                False                   False        188.88
#
# [5 rows x 21 columns]

# %% [markdown]
# We should update our training data to reflect this. We've kept our training data from Lab 2.

# %%
lab_2_data = pd.read_csv("data/task_2_wide_and_deep.csv")
lab_2_data.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        reviewerID        asin  overall  unixReviewTime brand category_0_0  \
# 0   ARA6X7G3KBX39  B00005B4BW      1.0      1042243200   NaN  Electronics
# 1  A231WM2Z2JL0U3  B00005B4BW      2.0       965433600   NaN  Electronics
# 2  A1O130H3XTF5WF  B00005B4BW      5.0       954460800   NaN  Electronics
# 3  A2IIZ25SZSQGCC  B00005B4BW      4.0      1030233600   NaN  Electronics
# 4  A2BBDPGILE8EN4  B00005B4BW      1.0      1009497600   NaN  Electronics
#
#      category_0_1       category_0_2  category_0_3 category_1_0  ...  \
# 0  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 1  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 2  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 3  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
# 4  Camera & Photo  Lighting & Studio  Photo Studio          NaN  ...
#
#   user_index item_index brand_index  als_prediction  user_embed_0  \
# 0     180332        781           0        3.105687      1.451223
# 1      55433        781           0        3.532970      1.650880
# 2      34202        781           0        3.962095      1.851401
# 3      77087        781           0        2.661104      1.243477
# 4      67012        781           0        3.232237      1.510355
#
#    user_embed_1  item_embed_0  item_embed_1  category_0_2_index  \
# 0     -2.425463      0.715103     -1.195170                  83
# 1     -2.759162      0.769520     -1.286120                  83
# 2     -3.094298      0.820172     -1.370778                  83
# 3     -2.078256      0.770355     -1.287510                  83
# 4     -2.524297      0.709057     -1.185062                  83
#
#    category_1_2_index
# 0                 101
# 1                 101
# 2                 101
# 3                 101
# 4                 101
#
# [5 rows x 34 columns]

# %%
lab_2_data.dtypes
# Out:
# reviewerID                   object
# asin                         object
# overall                     float64
# unixReviewTime                int64
# brand                        object
# category_0_0                 object
# category_0_1                 object
# category_0_2                 object
# category_0_3                 object
# category_1_0                 object
# category_1_1                 object
# category_1_2                 object
# category_1_3                 object
# salesRank_Electronics       float64
# salesRank_Camera            float64
# salesRank_Computers         float64
# salesRank_CellPhones        float64
# salesRank_CellPhones_NA        bool
# salesRank_Electronics_NA       bool
# salesRank_Camera_NA            bool
# salesRank_Computers_NA         bool
# price_filled                float64
# timeBreaker                 float64
# valid                          bool
# user_index                    int64
# item_index                    int64
# brand_index                   int64
# als_prediction              float64
# user_embed_0                float64
# user_embed_1                float64
# item_embed_0                float64
# item_embed_1                float64
# category_0_2_index            int64
# category_1_2_index            int64
# dtype: object

# %% [markdown]
# Update the `get_candidate_scoring_model` in [trainer.py](assessment/trainer.py) in order to calculate the [Gaussian Rank](https://medium.com/rapids-ai/gauss-rank-transformation-is-100x-faster-with-rapids-and-cupy-7c947e3397da) of our `metadata`'s `salesRank_Electronics` column. Then, join this column into `lab_2_data`.
#
# Finally, choose one of either ALS (`get_als_model`) or Wide and Deep model (`get_wide_and_deep_model`) to implement as the Candidate Scoring Model.
#
# Whether ALS or Wide and Deep is chosen, the Candidate Scoring Model needs to meet the following requirements:
#
# * The Candidate Scoring Model should be trained in less than 600 seconds `10 points`.
# * The Candidate Scoring Model should have a Root Mean Squared Error of less than 1.175 on the Validation Dataset `10 points`.
# * The Candidate Scoring Model should make predictions for the Validation Dataset in 30 seconds `10 points`.
#
# **While either algorithm can hypothetically pass these requirements, one will be significantly easier to implement than the other.** Run the below cell to verify that [trainer.py](assessment/trainer.py) has been correctly implemented for both Candidate Generation and Candidate Scoring, meeting all of the above requirements.

# %%
# !python3 -m assessment.trainer
# Out:
# 2021-12-15 22:36:22.307539: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-15 22:36:24.690295: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-15 22:36:24.690432: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-12-15 22:36:24.690613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:24.691220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-12-15 22:36:24.691269: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-15 22:36:24.691363: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-15 22:36:24.691397: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-15 22:36:24.691436: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-15 22:36:24.691486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-15 22:36:24.691546: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2021-12-15 22:36:24.691578: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-15 22:36:24.691617: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-15 22:36:24.691722: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:24.692331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:24.692847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1888] Adding visible gpu devices: 0
# RMSE 4.712260069180092
# RMSE 4.704371379481306
# RMSE 3.9071054306809296
# RMSE 1.9490392077778422
# RMSE 1.4963730279047407
# RMSE 1.3944705505969974
# RMSE 1.359263377398319
# RMSE 1.350976344800315
# RMSE 1.3421804175597705
# RMSE 1.3212587587853342
# RMSE 1.2917773001168387
# Candidate Generation Training Time 6.789770126342773
# Candidate Generation Prediction Time 0.002338409423828125
# Candidate Generation RMSE 1.2917773001168387
# sys:1: DtypeWarning: Columns (9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
# 2021-12-15 22:36:39.929119: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-15 22:36:39.929335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:39.929905: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-12-15 22:36:39.929968: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-15 22:36:39.930023: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-15 22:36:39.930039: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-15 22:36:39.930053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-15 22:36:39.930069: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-15 22:36:39.930084: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2021-12-15 22:36:39.930097: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-15 22:36:39.930124: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-15 22:36:39.930231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:39.930870: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:39.931384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1888] Adding visible gpu devices: 0
# 2021-12-15 22:36:39.931446: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-15 22:36:39.931581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1287] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-12-15 22:36:39.931601: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1293]      0
# 2021-12-15 22:36:39.931616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1306] 0:   N
# 2021-12-15 22:36:39.931710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:39.932236: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:39.932737: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:36:39.933203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7554 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5)
# 2021-12-15 22:36:40.923466: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-12-15 22:36:40.942635: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# Epoch 1/2
# 2021-12-15 22:36:42.068117: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-15 22:36:42.068559: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
#   85/1462 [>.............................] - ETA: 1:28 - loss: 8.4720 - rmse: 2.8295^C
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/dli/task/assessment/trainer.py", line 105, in <module>
#     cs_model = get_candidate_scoring_model()
#   File "/dli/task/assessment/trainer.py", line 74, in get_candidate_scoring_model
#     return get_wide_and_deep_model(lab_2_data)
#   File "/dli/task/assessment/trainer.py", line 42, in get_wide_and_deep_model
#     return wide_and_deep.get_wide_and_deep(
#   File "/dli/task/assessment/wide_and_deep.py", line 110, in get_wide_and_deep
#     model.fit(train_ds, callbacks=[KerasSequenceValidater(valid_ds)], epochs=2)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/training.py", line 1100, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py", line 855, in _call
#     return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py", line 2942, in __call__
#     return graph_function._call_flat(
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py", line 1918, in _call_flat
#     return self._build_call_outputs(self._inference_function.call(
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py", line 555, in call
#     outputs = execute.execute(
#   File "/usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# KeyboardInterrupt
# 2021-12-15 22:36:48.093503: W tensorflow/core/kernels/data/generator_dataset_op.cc:107] Error occurred when finalizing GeneratorDataset iterator: Failed precondition: Python interpreter state is not initialized. The process may be terminated.
# 	 [[{{node PyFunc}}]]

# %% [markdown]
# ## 2. Model Deployment
#
# If the above code passed, it should have saved the components for the Candidate Generation Model and the Candidate Scoring Model. We'll need to load them into Triton and our client application. Let's start with Triton.
#
# ### 2.1 Triton
#
# Open the File Browser (Ctrl/Command + Shift + F) to see the lab's file directory on the left (The list may need to be refreshed). The Candidate Scoring Model should now be saved to a folder on the left called `candidate_scorer`. Load it into `model_repository` using the following structure:
#
# `model_repository/
#   candidate_scorer/
#     config.pbtxt
#     1/
#       model.savedmodel/
#         <tensorflow_saved_model_files>/
#           ...
# `
#
# Feel free to use the [previous lab](3-03_triton.ipynb) as a guide. The below cell will **delete and rebuild** a `candidate_scorer` folder in `model_repository`. Please complete the `FIXME` below.

# %%
# !rm -rf model_repository/candidate_scorer ||:; mkdir model_repository/candidate_scorer

# %%
import tensorflow as tf
from nvtabular.inference.triton import export_tensorflow_model

model_name = 'candidate_scorer'
model = tf.keras.models.load_model(model_name)
tf_config = export_tensorflow_model(model, model_name, "model_repository/" + model_name, version=1)
# Out:
# INFO:tensorflow:Assets written to: model_repository/candidate_scorer/1/model.savedmodel/assets

# %% [markdown]
# Finally, let's verify that the model is running on Triton. `20 points`

# %%
import tritonhttpclient

try:
    triton_client = tritonhttpclient.InferenceServerClient(url="triton:8000", verbose=True)
    print("client created.")
except Exception as e:
    print("channel creation failed: " + str(e))

triton_client.get_model_repository_index()
triton_client.load_model(model_name=model_name)
triton_client.is_model_ready(model_name)
# Out:
# client created.
# POST v2/repository/index, headers None
#
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '77'}>
# bytearray(b'[{"name":"candidate_scorer"},{"name":"wnd_tf","version":"1","state":"READY"}]')
# POST v2/repository/models/candidate_scorer/load, headers None
#
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '0'}>
# Loaded model 'candidate_scorer'
# GET v2/models/candidate_scorer/ready, headers None
# <HTTPSocketPoolResponse status=200 headers={'content-length': '0', 'content-type': 'text/plain'}>
# True

# %% [markdown]
# Once verified, run the code below to free the GPU for the next section.

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %% [markdown]
# ### 2.2 Client Application
#
# We have our models, and our Candidate Scorer is loaded into Triton. Time for the magic to happen. Let's string everything together in [client.py](assessment/client.py) where there are a number of TODOs.
#
# First, load your Candidate Generation Model and use it to find a user's top 16 (`BATCH_SIZE`) recommendations.
# Second, specify the metadata columns specific to your Candidate Scoring Model.
# Finally, fix the `for` loop to format the data for Triton.
#
# For both the Candidate Generation Model and the Candidate Scoring Model, CuPy's/NumPy's [argpartition](https://numpy.org/doc/stable/reference/generated/numpy.argpartition.html) function are used to quickly separate top scoring items versus low scoring items.
#
# The following tests are in place:
# * Prediction for one user's top 16 items takes less than `2` seconds `10 points`
# * The average predicted score for user `131676`'s top 4 recommended items is greater than `4.2`. `10 points`

# %%
# !python3 -m assessment.client
# Out:
# 2021-12-15 22:50:14.594472: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-15 22:50:16.272063: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-12-15 22:50:16.272177: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-12-15 22:50:16.272342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:50:16.272866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Found device 0 with properties:
# pciBusID: 0000:00:1e.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-12-15 22:50:16.272905: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-15 22:50:16.272980: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-12-15 22:50:16.273014: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-12-15 22:50:16.273050: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-12-15 22:50:16.273084: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-12-15 22:50:16.273136: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.11
# 2021-12-15 22:50:16.273170: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-12-15 22:50:16.273206: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-12-15 22:50:16.273296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:50:16.273826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1038] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-15 22:50:16.274307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1888] Adding visible gpu devices: 0
# client created.
# POST v2/models/candidate_scorer/infer, headers {'Inference-Header-Content-Length': 770}
# b'{"inputs":[{"name":"user_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"item_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"brand_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"price_filled","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"salesRank_Electronics","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"category_0_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"category_1_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}}],"outputs":[{"name":"tf.__operators__.add","parameters":{"binary_data":false}}]}\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\x03\xe7\x00\x00\x10\xe6\x00\x00\x8e\t\x00\x00\x8ah\x00\x00\xfb\x96\x00\x00\xe3f\x00\x00\xe2\xe1\x00\x00\x84\xed\x00\x00`\xdb\x00\x00\x89\xed\x00\x00L\xc8\x00\x00\xb5\xb8\x00\x00&\xf5\x00\x00?\x16\x00\x00\x86\xe9\x00\x00A\xc9\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xea\x00\x00\x00\xae\x06\x00\x00\xfe\x04\x00\x00\xd1\n\x00\x00\x00\x00\x00\x00\xa5\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00T\x08\x00\x00\x00\x00\x00\x00\xb9\x02\x00\x00.\x05\x00\x00O\xca~;[\xa5\xf3?4\xee\x85?\x9e\x93\x84?E\xeb\x13\xbf\xfe\x813?=V6\xbf\x13\x88\x9d\xbf\x89\xfc\x1a@E\x1d\xa4\xbe\xf7h\xde=[\xa5\xf3?\x8c\x9b\xd7?G.\x1b?\x9b\x1c^\xbf\x95\xa9\x92\xbf\xbc\x1a\x8b?\xbb\x82\x88?a\xebQ\xbf\x8f\x14Y\xbd;\x8f|>\xdb\xbd\x82\xbd\xbe\x80|?\xf7\x1a\xa1?\x8d\x05b?;\x9c\x07\xc0\xf1\x7f&?\x8e]\x01?!\xd1\xd5?Op,\xbf\x1a\xb4\x92?\x15\x14)?\x0b\x00\x00\x00Q\x00\x00\x00^\x00\x00\x005\x00\x00\x00?\x00\x00\x00P\x00\x00\x00\x1c\x00\x00\x00\x1c\x00\x00\x00Q\x00\x00\x00P\x00\x00\x00\x01\x00\x00\x00Q\x00\x00\x00\x9a\x00\x00\x00^\x00\x00\x00U\x00\x00\x00\x1c\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00'
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '429'}>
# bytearray(b'{"model_name":"candidate_scorer","model_version":"1","outputs":[{"name":"tf.__operators__.add","datatype":"FP32","shape":[16,1],"data":[4.320802211761475,3.7253682613372804,3.065422296524048,4.064028739929199,4.378695964813232,3.4947307109832765,4.3867411613464359,4.483827114105225,4.061656951904297,3.5355112552642824,3.415954113006592,3.80899977684021,4.05785608291626,3.702258825302124,4.104137420654297,4.336055755615234]}]}')
# Ranking Time 0.6419599056243896
# Top Indexes [51521 57826 38651 60804]
# Top Predictions [4.33605576 4.38674116 4.37869596 4.48382711]
# Average Rating 4.396329998970032
# Tests pass!

# %% [markdown]
# Got both `Tests pass!` for [1. Model Training](#1.-Model-Training) and [2. Model Deployment](#2.-Model-Deployment)? Run the cell below for the final check! This will verify your code against our assessment server, and if it passes, will qualify you for a certificate.

# %%
from run_assessment import run_assessment
run_assessment()
# Out:
# client created.
# RMSE 4.731586072533289
# RMSE 4.750770919486995
# RMSE 4.248600593093815
# RMSE 2.2753053385295168
# RMSE 1.5332547470412954
# RMSE 1.3700755772354463
# RMSE 1.2955153688519607
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3357: DtypeWarning: Columns (9,10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Epoch 1/2
# 1462/1462 [==============================] - 106s 72ms/step - loss: 2.3671 - rmse: 1.4666
# {'val_loss': 2.4458036, 'val_rmse': 1.198361}
# Epoch 2/2
# 1462/1462 [==============================] - 99s 68ms/step - loss: 0.9742 - rmse: 0.9869
# {'val_loss': 2.1481478, 'val_rmse': 1.0166978}
# GET v2/models/candidate_scorer/ready, headers None
# <HTTPSocketPoolResponse status=200 headers={'content-length': '0', 'content-type': 'text/plain'}>
# POST v2/models/candidate_scorer/infer, headers {'Inference-Header-Content-Length': 770}
# b'{"inputs":[{"name":"user_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"item_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"brand_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"price_filled","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"salesRank_Electronics","shape":[16,1],"datatype":"FP32","parameters":{"binary_data_size":64}},{"name":"category_0_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}},{"name":"category_1_2_index","shape":[16,1],"datatype":"INT32","parameters":{"binary_data_size":64}}],"outputs":[{"name":"tf.__operators__.add","parameters":{"binary_data":false}}]}\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\\\x02\x02\x00\x03\xe7\x00\x00\x10\xe6\x00\x00\x8e\t\x00\x00\x8ah\x00\x00\xfb\x96\x00\x00\xe3f\x00\x00\xe2\xe1\x00\x00\x84\xed\x00\x00`\xdb\x00\x00\x89\xed\x00\x00L\xc8\x00\x00\xb5\xb8\x00\x00&\xf5\x00\x00?\x16\x00\x00\x86\xe9\x00\x00A\xc9\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xea\x00\x00\x00\xae\x06\x00\x00\xfe\x04\x00\x00\xd1\n\x00\x00\x00\x00\x00\x00\xa5\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00T\x08\x00\x00\x00\x00\x00\x00\xb9\x02\x00\x00.\x05\x00\x00O\xca~;[\xa5\xf3?4\xee\x85?\x9e\x93\x84?E\xeb\x13\xbf\xfe\x813?=V6\xbf\x13\x88\x9d\xbf\x89\xfc\x1a@E\x1d\xa4\xbe\xf7h\xde=[\xa5\xf3?\x8c\x9b\xd7?G.\x1b?\x9b\x1c^\xbf\x95\xa9\x92\xbf\xbc\x1a\x8b?\xbb\x82\x88?a\xebQ\xbf\x8f\x14Y\xbd;\x8f|>\xdb\xbd\x82\xbd\xbe\x80|?\xf7\x1a\xa1?\x8d\x05b?;\x9c\x07\xc0\xf1\x7f&?\x8e]\x01?!\xd1\xd5?Op,\xbf\x1a\xb4\x92?\x15\x14)?\x0b\x00\x00\x00Q\x00\x00\x00^\x00\x00\x005\x00\x00\x00?\x00\x00\x00P\x00\x00\x00\x1c\x00\x00\x00\x1c\x00\x00\x00Q\x00\x00\x00P\x00\x00\x00\x01\x00\x00\x00Q\x00\x00\x00\x9a\x00\x00\x00^\x00\x00\x00U\x00\x00\x00\x1c\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00e\x00\x00\x00'
# <HTTPSocketPoolResponse status=200 headers={'content-type': 'application/json', 'content-length': '429'}>
# bytearray(b'{"model_name":"candidate_scorer","model_version":"1","outputs":[{"name":"tf.__operators__.add","datatype":"FP32","shape":[16,1],"data":[4.320802211761475,3.7253682613372804,3.065422296524048,4.064028739929199,4.378695964813232,3.4947307109832765,4.3867411613464359,4.483827114105225,4.061656951904297,3.5355112552642824,3.415954113006592,3.80899977684021,4.05785608291626,3.702258825302124,4.104137420654297,4.336055755615234]}]}')
# Congratulations! You passed the assessment!
# See instructions below to generate a certificate.

# %% [markdown]
# ## Generate a Certificate
# If you passed the assessment, please return to the course page (shown below) and click the "ASSESS TASK" button, which will generate your certificate for the course.
#
# <img src="images/run_assess_task.png" height="300" width="500"/>

# %% [markdown]
# <div align="center"><a href="https://www.nvidia.com/en-us/deep-learning-ai/education/"><img src="./images/DLI_Header.png"></a></div>
